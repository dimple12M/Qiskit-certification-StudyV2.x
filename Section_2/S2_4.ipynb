# %% [markdown]
# > # SECTION -2
#
# <h4>
#
# ---
#
# ***DEVICE visualization***
#
# 1. error map
# 2. gate map
# 3. coupling map
# 4. circuit layout
#
# ---
#
# </h4>
# REFERENCE :
#
#  https://quantum.cloud.ibm.com/docs/en/api/qiskit/visualization

# %%
from platform import python_version
import qiskit
print("Python version ", python_version())
print(f"Qiskit version: {qiskit.__version__}")
# Out:
# Python version  3.13.5
# Qiskit version: 2.5.0

# %% [markdown]
# > # plot gate map
#
# Physical qubit connectivity
#
# REFERENCE: https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.visualization.plot_gate_map

# %%
from qiskit_ibm_runtime.fake_provider import FakePerth
from qiskit.visualization import plot_gate_map

backend = FakePerth()

plot_gate_map(backend)

# %% [markdown]
# > # plot error map
#
# Plots the error map of a given backend.
#
# REFERENCE: https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.visualization.plot_error_map

# %%
from qiskit.visualization import plot_error_map
plot_error_map(backend, figsize=(8,6))

# %% [markdown]
# > # plot coupling map
#
# Plots an arbitrary coupling map of qubits (embedded in a plane).
#
# REFERENCE: https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.visualization.plot_coupling_map

# %%
from qiskit.visualization import plot_coupling_map

num_qubits = 8
qubit_coordinates = [[0, 1], [1, 1], [1, 0], [1, 2], [2, 0], [2, 2], [2, 1], [3, 1]]
coupling_map = [[0, 1], [1, 2], [2, 3], [3, 5], [4, 5], [5, 6], [2, 4], [6, 7]]
plot_coupling_map(num_qubits, qubit_coordinates, coupling_map)

# %% [markdown]
# > # plot_circuit_layout
#
# Plot the layout of a circuit transpiled for a given target backend.
#
# REFERENCE: https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.visualization.plot_circuit_layout

# %%
from math import pi
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector


qc=QuantumCircuit(2,2)
qc.h(0)
qc.x(1)
qc.draw(output="mpl")

# %%
from qiskit.providers.fake_provider import GenericBackendV2
from qiskit.visualization import plot_circuit_layout
from qiskit import QuantumCircuit, transpile



backend = GenericBackendV2(num_qubits=5)
new_circ_lv3 = transpile(qc, backend=backend, optimization_level=3)
plot_circuit_layout(new_circ_lv3, backend)

# %% [markdown]
# > # DAG Visualizations

# %% [markdown]
# > # dag_drawer
#
# Plot the directed acyclic graph (dag) to represent operation dependencies in a quantum circuit.
#
# This function calls the graphviz_draw() function from the rustworkx package to draw the DAG.
#
# REFERENCE: https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.visualization.dag_drawer

# %%
from qiskit.converters import circuit_to_dag
from qiskit.visualization import dag_drawer
dag = circuit_to_dag(qc)

style = {
    "inputnodecolor": "pink",
    "outputnodecolor": "lightblue",
    "opnodecolor": "red",
}

dag_drawer(dag, style=style)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=270x215>
